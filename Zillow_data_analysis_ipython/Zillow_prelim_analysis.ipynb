# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
df_properties2016 = pd.read_csv("/home/mishraka/repos/Data_Science/Zillow_data/properties_2016.csv")
# Out:
# /home/mishraka/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_properties2016.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# ...

# %%
df_properties2016.isna().sum()
# Out:
# parcelid                              0
# airconditioningtypeid           2173698
# architecturalstyletypeid        2979156
# basementsqft                    2983589
# bathroomcnt                       11462
# bedroomcnt                        11450
# buildingclasstypeid             2972588
# buildingqualitytypeid           1046729
# calculatedbathnbr                128912
# decktypeid                      2968121
# finishedfloor1squarefeet        2782500
# calculatedfinishedsquarefeet      55565
# finishedsquarefeet12             276033
# finishedsquarefeet13            2977545
# finishedsquarefeet15            2794419
# finishedsquarefeet50            2782500
# finishedsquarefeet6             2963216
# fips                              11437
# fireplacecnt                    2672580
# fullbathcnt                      128912
# garagecarcnt                    2101950
# garagetotalsqft                 2101950
# hashottuborspa                  2916203
# ...

# %%
df_properties2016.shape
# Out:
# (2985217, 58)

# %%
df_properties2017 = pd.read_csv("/home/mishraka/repos/Data_Science/Zillow_data/properties_2017.csv")
# Out:
# /home/mishraka/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
