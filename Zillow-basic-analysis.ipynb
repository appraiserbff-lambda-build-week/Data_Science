# %%
# Import the important libraries
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# current directory
pwd
# Out:
# '/home/ec2-user/SageMaker/Zillow_data_Analysis'

# %%
# list of the files in the directory
# !ls
# Out:
# dask-worker-space    sample_submission.csv  Zillow-basic-analysis.ipynb
# properties_2016.csv  train_2016_v2.csv
# properties_2017.csv  train_2017.csv

# %%
df_properties_2016 = pd.read_csv('properties_2016.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_properties_2016.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# ...

# %%
df_properties_2016.isna().sum()
# Out:
# parcelid                              0
# airconditioningtypeid           2173698
# architecturalstyletypeid        2979156
# basementsqft                    2983589
# bathroomcnt                       11462
# bedroomcnt                        11450
# buildingclasstypeid             2972588
# buildingqualitytypeid           1046729
# calculatedbathnbr                128912
# decktypeid                      2968121
# finishedfloor1squarefeet        2782500
# calculatedfinishedsquarefeet      55565
# finishedsquarefeet12             276033
# finishedsquarefeet13            2977545
# finishedsquarefeet15            2794419
# finishedsquarefeet50            2782500
# finishedsquarefeet6             2963216
# fips                              11437
# fireplacecnt                    2672580
# fullbathcnt                      128912
# garagecarcnt                    2101950
# garagetotalsqft                 2101950
# hashottuborspa                  2916203
# ...

# %%
df_properties_2016.shape
# Out:
# (2985217, 58)

# %%
df_properties_2017 = pd.read_csv('properties_2017.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_properties_2017.shape
# Out:
# (192465, 58)

# %%
df_properties_2017.isna().sum()
# Out:
# parcelid                             0
# airconditioningtypeid           111690
# architecturalstyletypeid        153654
# basementsqft                    153862
# bathroomcnt                          2
# bedroomcnt                           1
# buildingclasstypeid             153243
# buildingqualitytypeid            53447
# calculatedbathnbr                 6130
# decktypeid                      152978
# finishedfloor1squarefeet        142790
# calculatedfinishedsquarefeet      2187
# finishedsquarefeet12             13360
# finishedsquarefeet13            153525
# finishedsquarefeet15            144282
# finishedsquarefeet50            142790
# finishedsquarefeet6             152876
# fips                                 0
# fireplacecnt                    137648
# fullbathcnt                       6130
# garagecarcnt                    108341
# garagetotalsqft                 108341
# hashottuborspa                  151464
# heatingorsystemtypeid            57264
# ...

# %%
df_properties_2017.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  5.0                    NaN
# 3          0.0         0.0                  3.0                    6.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# ...

# %%
df_train_2016_2017 = pd.concat([pd.read_csv('train_2016_v2.csv', parse_dates=['transactiondate']), pd.read_csv('train_2017.csv', parse_dates=['transactiondate'])])

# %%
df_train_2016_2017.shape
# Out:
# (167888, 3)

# %%
df_train_2016_2017.isna().sum()
# Out:
# parcelid           0
# logerror           0
# transactiondate    0
# dtype: int64

# %%
df_train_2016_2017.head(20)
# Out:
#     parcelid  logerror transactiondate
# 0   11016594    0.0276      2016-01-01
# 1   14366692   -0.1684      2016-01-01
# 2   12098116   -0.0040      2016-01-01
# 3   12643413    0.0218      2016-01-02
# 4   14432541   -0.0050      2016-01-02
# 5   11509835   -0.2705      2016-01-02
# 6   12286022    0.0440      2016-01-02
# 7   17177301    0.1638      2016-01-02
# 8   14739064   -0.0030      2016-01-02
# 9   14677559    0.0843      2016-01-03
# 10  10854446    0.3825      2016-01-03
# 11  11672170   -0.0161      2016-01-03
# 12  10949761    0.0344      2016-01-03
# 13  14665244    0.0816      2016-01-03
# 14  14148540   -0.0450      2016-01-03
# 15  14057104    0.0020      2016-01-03
# 16  17296797    0.0440      2016-01-03
# 17  12524288   -0.0419      2016-01-03
# 18  14091502   -0.0020      2016-01-03
# 19  10815909    0.0100      2016-01-03

# %%
df_properties_16_17 = pd.concat([pd.read_csv("properties_2016.csv"), pd.read_csv("properties_2017.csv")])
pd.set_option('display.max_columns', None)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_properties_16_17.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# ...

# %%
df_properties_16_17.shape
# Out:
# (5970434, 58)

# %%
df_properties_16_17.dtypes
# Out:
# parcelid                          int64
# airconditioningtypeid           float64
# architecturalstyletypeid        float64
# basementsqft                    float64
# bathroomcnt                     float64
# bedroomcnt                      float64
# buildingclasstypeid             float64
# buildingqualitytypeid           float64
# calculatedbathnbr               float64
# decktypeid                      float64
# finishedfloor1squarefeet        float64
# calculatedfinishedsquarefeet    float64
# finishedsquarefeet12            float64
# finishedsquarefeet13            float64
# finishedsquarefeet15            float64
# finishedsquarefeet50            float64
# finishedsquarefeet6             float64
# fips                            float64
# fireplacecnt                    float64
# fullbathcnt                     float64
# garagecarcnt                    float64
# garagetotalsqft                 float64
# hashottuborspa                   object
# ...

# %%
df_properties_16_17.isna().sum()
# Out:
# parcelid                              0
# airconditioningtypeid           2872824
# architecturalstyletypeid        3939566
# basementsqft                    3945357
# bathroomcnt                       11470
# bedroomcnt                        11453
# buildingclasstypeid             3930730
# buildingqualitytypeid           1381330
# calculatedbathnbr                165801
# decktypeid                      3924826
# finishedfloor1squarefeet        3678651
# calculatedfinishedsquarefeet      69081
# finishedsquarefeet12             360488
# finishedsquarefeet13            3937274
# finishedsquarefeet15            3695206
# finishedsquarefeet50            3678651
# finishedsquarefeet6             3918606
# fips                              11437
# fireplacecnt                    3534048
# fullbathcnt                      165801
# garagecarcnt                    2777900
# garagetotalsqft                 2777900
# hashottuborspa                  3862349
# ...

# %%
train_properties_merge = pd.merge(df_train_2016_2017, df_properties_16_17, on=['parcelid'], how='inner')

# %%
train_properties_merge.head()
# Out:
#    parcelid  logerror transactiondate  airconditioningtypeid  \
# 0  11016594  0.027600      2016-01-01                    1.0
# 1  11016594  0.027600      2016-01-01                    1.0
# 2  14366692 -0.168400      2016-01-01                    NaN
# 3  14366692 -0.168400      2016-01-01                    NaN
# 4  14366692  0.002142      2017-08-04                    NaN
#
#    architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                       NaN           NaN          2.0         3.0
# 1                       NaN           NaN          2.0         3.0
# 2                       NaN           NaN          3.5         4.0
# 3                       NaN           NaN          3.5         4.0
# 4                       NaN           NaN          3.5         4.0
#
#    buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# 0                  NaN                    4.0                2.0         NaN
# ...

# %%
train_properties_merge.shape
# Out:
# (335776, 60)

# %%
train_properties_merge.describe()
# Out:
#            parcelid       logerror  airconditioningtypeid  \
# count  3.357760e+05  335776.000000          107623.000000
# mean   1.299536e+07       0.013906               1.816182
# std    3.016067e+06       0.165706               2.972051
# min    1.071174e+07      -4.655420               1.000000
# 25%    1.154899e+07      -0.025300               1.000000
# 50%    1.254060e+07       0.006000               1.000000
# 75%    1.421930e+07       0.039200               1.000000
# max    1.676893e+08       5.262999              13.000000
#
#        architecturalstyletypeid  basementsqft    bathroomcnt     bedroomcnt  \
# count                936.000000    186.000000  335601.000000  335601.000000
# mean                   7.299145    695.376344       2.290604       3.044094
# std                    2.718178    582.371757       1.000292       1.146661
# min                    2.000000     38.000000       0.000000       0.000000
# ...

# %%
df_properties_16_17.isnull().sum()
# Out:
# parcelid                              0
# airconditioningtypeid           4343553
# architecturalstyletypeid        5958312
# basementsqft                    5967179
# bathroomcnt                       14419
# bedroomcnt                        14395
# buildingclasstypeid             5945074
# buildingqualitytypeid           2090551
# calculatedbathnbr                246068
# decktypeid                      5935959
# finishedfloor1squarefeet        5563959
# calculatedfinishedsquarefeet     100662
# finishedsquarefeet12             540464
# finishedsquarefeet13            5955091
# finishedsquarefeet15            5589451
# finishedsquarefeet50            5563959
# finishedsquarefeet6             5926951
# fips                              14369
# fireplacecnt                    5344673
# fullbathcnt                      246068
# garagecarcnt                    4196159
# garagetotalsqft                 4196159
# hashottuborspa                  5851358
# ...

# %%
df_missing_values = df_properties_16_17.isnull().sum(axis=0).reset_index()
df_missing_values.columns=['column_name', 'missing_count']
df_missing_values=df_missing_values.ix[df_missing_values['missing_count']>0]
df_missing_values=df_missing_values.sort_values(by='missing_count')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   app.launch_new_instance()

# %%
df_missing_values.head(20)
# Out:
#                      column_name  missing_count
# 35        rawcensustractandblock          14369
# 25                     longitude          14369
# 24                      latitude          14369
# 37                regionidcounty          14369
# 17                          fips          14369
# 33         propertylandusetypeid          14369
# 52                assessmentyear          14372
# 5                     bedroomcnt          14395
# 4                    bathroomcnt          14419
# 40                       roomcnt          14444
# 32     propertycountylandusecode          15276
# 39                   regionidzip          26694
# 54                     taxamount          54002
# 51             taxvaluedollarcnt          76816
# 11  calculatedfinishedsquarefeet         100662
# 50    structuretaxvaluedollarcnt         101446
# 47                     yearbuilt         107761
# 36                  regionidcity         124973
# 53         landtaxvaluedollarcnt         127659
# ...

# %%
#  Let's plot the missing values
ind = np.arange(df_missing_values.shape[0])
width = 0.9
fig, ax = plt.subplots(figsize = (12,18))
rects = ax.barh(ind, df_missing_values.missing_count.values, color='blue')
ax.set_yticks(ind)
ax.set_yticklabels(df_missing_values.column_name.values, rotation='horizontal')
ax.set_xlabel("Count of Missing values")
ax.set_title("Missing values in each column")
plt.show()

# %%
df_properties_16_17.columns
# Out:
# Index(['parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15',
#        'finishedsquarefeet50', 'finishedsquarefeet6', 'fips', 'fireplacecnt',
#        'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa',
#        'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertylandusetypeid',
#        'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt',
#        'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid',
# ...

# %%
df_selected_columns = df_properties_16_17[['rawcensustractandblock','latitude', 'longitude', 'regionidcounty', 'fips',
                                         'propertylandusetypeid', 'assessmentyear', 'bedroomcnt', 'bathroomcnt', 'roomcnt',
                                         'regionidzip', 'taxamount', 'landtaxvaluedollarcnt',
                                          'regionidcity', 'yearbuilt', 'structuretaxvaluedollarcnt', 'calculatedfinishedsquarefeet',
                                          'taxvaluedollarcnt']]

# %%
df_selected_columns.head(100)
# Out:
#     rawcensustractandblock    latitude    longitude  regionidcounty    fips  \
# 0             6.037800e+07  34144442.0 -118654084.0          3101.0  6037.0
# 1             6.037800e+07  34140430.0 -118625364.0          3101.0  6037.0
# 2             6.037703e+07  33989359.0 -118394633.0          3101.0  6037.0
# 3             6.037141e+07  34148863.0 -118437206.0          3101.0  6037.0
# 4             6.037123e+07  34194168.0 -118385816.0          3101.0  6037.0
# 5             6.037125e+07  34171873.0 -118380906.0          3101.0  6037.0
# 6             6.037144e+07  34131929.0 -118351474.0          3101.0  6037.0
# 7             6.037311e+07  34171345.0 -118314900.0          3101.0  6037.0
# 8             6.037310e+07  34218210.0 -118331311.0          3101.0  6037.0
# 9             6.037320e+07  34289776.0 -118432085.0          3101.0  6037.0
# 10            6.037111e+07  34265214.0 -118520217.0          3101.0  6037.0
# ...

# %%
571346.0 + 1156834.0
# Out:
# 1728180.0

# %%
df_selected_columns.isna().sum()
# Out:
# rawcensustractandblock           14369
# latitude                         14369
# longitude                        14369
# regionidcounty                   14369
# fips                             14369
# propertylandusetypeid            14369
# assessmentyear                   14372
# bedroomcnt                       14395
# bathroomcnt                      14419
# roomcnt                          14444
# propertycountylandusecode        15276
# regionidzip                      26694
# taxamount                        54002
# landtaxvaluedollarcnt           127659
# regionidcity                    124973
# yearbuilt                       107761
# structuretaxvaluedollarcnt      101446
# calculatedfinishedsquarefeet    100662
# taxvaluedollarcnt                76816
# dtype: int64

# %%
df_selected_columns.dtypes
# Out:
# rawcensustractandblock          float64
# latitude                        float64
# longitude                       float64
# regionidcounty                  float64
# fips                            float64
# propertylandusetypeid           float64
# assessmentyear                  float64
# bedroomcnt                      float64
# bathroomcnt                     float64
# roomcnt                         float64
# regionidzip                     float64
# taxamount                       float64
# landtaxvaluedollarcnt           float64
# regionidcity                    float64
# yearbuilt                       float64
# structuretaxvaluedollarcnt      float64
# calculatedfinishedsquarefeet    float64
# taxvaluedollarcnt               float64
# dtype: object

# %%
df_selected_columns.shape
# Out:
# (5970434, 18)

# %%
df_no_na = df_selected_columns.dropna()

# %%
df_no_na.isna().sum()
# Out:
# rawcensustractandblock          0
# latitude                        0
# longitude                       0
# regionidcounty                  0
# fips                            0
# propertylandusetypeid           0
# assessmentyear                  0
# bedroomcnt                      0
# bathroomcnt                     0
# roomcnt                         0
# regionidzip                     0
# taxamount                       0
# landtaxvaluedollarcnt           0
# regionidcity                    0
# yearbuilt                       0
# structuretaxvaluedollarcnt      0
# calculatedfinishedsquarefeet    0
# taxvaluedollarcnt               0
# dtype: int64

# %%
df_no_na.shape
# Out:
# (5682381, 18)

# %%
df_no_na['appraised_value_y'] = df_no_na['structuretaxvaluedollarcnt'] + df_no_na['taxvaluedollarcnt']
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_no_na.head(20)
# Out:
#     rawcensustractandblock    latitude    longitude  regionidcounty    fips  \
# 3             6.037141e+07  34148863.0 -118437206.0          3101.0  6037.0
# 4             6.037123e+07  34194168.0 -118385816.0          3101.0  6037.0
# 5             6.037125e+07  34171873.0 -118380906.0          3101.0  6037.0
# 7             6.037311e+07  34171345.0 -118314900.0          3101.0  6037.0
# 9             6.037320e+07  34289776.0 -118432085.0          3101.0  6037.0
# 10            6.037111e+07  34265214.0 -118520217.0          3101.0  6037.0
# 17            6.037901e+07  34690736.0 -118135225.0          3101.0  6037.0
# 18            6.037900e+07  34733960.0 -118139298.0          3101.0  6037.0
# 19            6.037910e+07  34560018.0 -118169806.0          3101.0  6037.0
# 20            6.037235e+07  33986910.0 -118329553.0          3101.0  6037.0
# 22            6.037601e+07  33959896.0 -118350438.0          3101.0  6037.0
# ...

# %%
df_no_na.shape
# Out:
# (5682381, 19)

# %%
df_no_na_int = df_no_na.astype(np.int)

# %%
df_no_na_int.head()
# Out:
#    rawcensustractandblock  latitude  longitude  regionidcounty  fips  \
# 3                60371412  34148863 -118437206            3101  6037
# 4                60371232  34194168 -118385816            3101  6037
# 5                60371252  34171873 -118380906            3101  6037
# 7                60373108  34171345 -118314900            3101  6037
# 9                60373202  34289776 -118432085            3101  6037
#
#    propertylandusetypeid  assessmentyear  bedroomcnt  bathroomcnt  roomcnt  \
# 3                     47            2015           0            0        0
# 4                     31            2015           0            0        0
# 5                     31            2015           0            0        0
# 7                     31            2015           0            0        0
# 9                     31            2015           0            0        0
#
#    regionidzip  taxamount  landtaxvaluedollarcnt  regionidcity  yearbuilt  \
# ...

# %%
df_no_na_int.shape
# Out:
# (5682381, 19)

# %%
df_no_na_int.corr()
# Out:
#                               rawcensustractandblock  latitude  longitude  \
# rawcensustractandblock                      1.000000 -0.038892  -0.354878
# latitude                                   -0.038892  1.000000  -0.576031
# longitude                                  -0.354878 -0.576031   1.000000
# regionidcounty                             -0.617617  0.568426  -0.367010
# fips                                        0.999942 -0.043041  -0.351965
# propertylandusetypeid                       0.053028 -0.006913   0.014364
# assessmentyear                              0.000465 -0.000310   0.000304
# bedroomcnt                                  0.025228  0.033263   0.003520
# bathroomcnt                                -0.046111  0.050892  -0.033734
# roomcnt                                     0.715188 -0.233540  -0.025820
# regionidzip                                 0.055465  0.001683   0.032190
# taxamount                                  -0.017113 -0.047743  -0.026211
# ...

# %%
df_no_na_int.columns
# Out:
# Index(['rawcensustractandblock', 'latitude', 'longitude', 'regionidcounty',
#        'fips', 'propertylandusetypeid', 'assessmentyear', 'bedroomcnt',
#        'bathroomcnt', 'roomcnt', 'regionidzip', 'taxamount',
#        'landtaxvaluedollarcnt', 'regionidcity', 'yearbuilt',
#        'structuretaxvaluedollarcnt', 'calculatedfinishedsquarefeet',
#        'taxvaluedollarcnt', 'appraised_value_y'],
#       dtype='object')

# %%
# let's define our X and y
X = df_no_na_int[['latitude', 'longitude', 'regionidcounty',
       'fips', 'propertylandusetypeid', 'assessmentyear', 'bedroomcnt',
       'bathroomcnt', 'roomcnt', 'regionidzip', 'taxamount',
       'landtaxvaluedollarcnt', 'regionidcity', 'yearbuilt',
        'calculatedfinishedsquarefeet'
        ]]

# %%
X.head()
# Out:
#    latitude  longitude  regionidcounty  fips  propertylandusetypeid  \
# 3  34148863 -118437206            3101  6037                     47
# 4  34194168 -118385816            3101  6037                     31
# 5  34171873 -118380906            3101  6037                     31
# 7  34171345 -118314900            3101  6037                     31
# 9  34289776 -118432085            3101  6037                     31
#
#    assessmentyear  bedroomcnt  bathroomcnt  roomcnt  regionidzip  taxamount  \
# 3            2015           0            0        0        96424      14557
# 4            2015           0            0        0        96450       5725
# 5            2015           0            0        0        96446       3661
# 7            2015           0            0        0        96434       7857
# 9            2015           0            0        0        96366       4054
#
#    landtaxvaluedollarcnt  regionidcity  yearbuilt  \
# ...

# %%
y = df_no_na_int['appraised_value_y']

# %%
y.head()
# Out:
# 3    1728180
# 4     627287
# 5     459698
# 7     790484
# 9     479641
# Name: appraised_value_y, dtype: int64

# %%
X.shape, y.shape
# Out:
# ((5682381, 15), (5682381,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, shuffle=True)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4261785, 15), (1420596, 15), (4261785,), (1420596,))

# %%
y_test
# Out:
# 2413376     582490
# 1156693     355659
# 303860       53159
# 2686504     265845
# 176479     2175913
# 21374       201582
# 254044     1524000
# 151564      464272
# 102963      750347
# 451009      634700
# 989294     1076165
# 78123       296349
# 1333958     241544
# 1583742     135000
# 2175845     412301
# 2911269     393146
# 1949296     906225
# 2157870     560459
# 1176426     803481
# 215393      236590
# 882086       46428
# 461633      572300
# 520372     1727817
# 2240434     236145
# 1239446      88473
# 1358135     292581
# 1550426     222485
# 387301      283666
# 1278880     123781
# 429926      379910
#             ...
# 1275049     506655
# 781965      356656
# 1497610     736973
# 2108904     531378
# 1954415     885133
# 2389526     500910
# 2014248      40321
# 2711807    1269146
# 832679     1797574
# 1959418     417382
# 1566523     753055
# 2122411    1183894
# 9253        763400
# 2827097     365120
# 117739      290049
# 2538447      91900
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model = LinearRegression()
model.fit(X_train, y_train)

print("Coefficient: \n", model.coef_)
print("\n Intercept: ", model.intercept_)
# Out:
# Coefficient:
#  [-6.41706645e-02  2.87116246e-02  3.15438285e+01  1.73303727e+03
#   1.19002270e+03  2.93771312e+04 -1.54295235e+04  9.76985868e+03
#   2.48080375e+03 -6.14587896e-01  1.22548897e+02 -2.64926886e-01
#   6.85432406e-02  7.30257718e+02  5.09948378e+01]
#
#  Intercept:  -65942215.65452539

# %%
y_test_predict = model.predict(X_test)

# %%
y_test_predict.shape
# Out:
# (1420596,)

# %%
MSE = mean_squared_error(y_test, y_test_predict)

RMSE = (np.sqrt(mean_squared_error(y_test, y_test_predict)))

print('MSE is {}'.format(MSE))
print('RMSE is {}'.format(RMSE))

R2 = r2_score(y_test, y_test_predict)

print('R^2 is {}'.format(R2))
# Out:
# MSE is 55468022187.655266
# RMSE is 235516.50088190267
# R^2 is 0.9465973557921307

# %% [markdown]
# ## Polynomial Regression

# %%
df_for_poly_reg = df_no_na_int[['latitude', 'longitude', 'regionidcounty',
       'fips', 'propertylandusetypeid', 'assessmentyear', 'bedroomcnt',
       'bathroomcnt', 'roomcnt', 'regionidzip', 'taxamount',
       'landtaxvaluedollarcnt', 'regionidcity', 'yearbuilt',
        'calculatedfinishedsquarefeet',
        'appraised_value_y']]

# %%
df_for_poly_reg['ln_price'] = np.log(df_for_poly_reg['appraised_value_y'])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_for_poly_reg.appraised_value_y.describe()
# Out:
# count    5.682381e+06
# mean     6.048730e+05
# std      1.026315e+06
# min      3.300000e+01
# 25%      2.807910e+05
# 50%      4.485370e+05
# 75%      6.948060e+05
# max      5.424196e+08
# Name: appraised_value_y, dtype: float64

# %%
df_for_poly_reg.appraised_value_y.hist()

# %%
df_for_poly_reg.ln_price.hist()

# %%
df_for_poly_reg.ln_price.describe()
# Out:
# count    5.682381e+06
# mean     1.297689e+01
# std      7.971901e-01
# min      3.496508e+00
# 25%      1.254537e+01
# 50%      1.301375e+01
# 75%      1.345139e+01
# max      2.011155e+01
# Name: ln_price, dtype: float64

# %%
df_for_poly_reg.columns
# Out:
# Index(['latitude', 'longitude', 'regionidcounty', 'fips',
#        'propertylandusetypeid', 'assessmentyear', 'bedroomcnt', 'bathroomcnt',
#        'roomcnt', 'regionidzip', 'taxamount', 'landtaxvaluedollarcnt',
#        'regionidcity', 'yearbuilt', 'calculatedfinishedsquarefeet',
#        'appraised_value_y', 'ln_price'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


X = df_for_poly_reg.drop(['appraised_value_y', 'ln_price'], axis=1)
y= df_for_poly_reg['ln_price']

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=.25, random_state=42, shuffle=True)

model = LinearRegression()
model.fit(X_train, y_train)

y_test_predict = model.predict(X_test)

MSE = mean_squared_error(y_test, y_test_predict)

RMSE = (np.sqrt(mean_squared_error(y_test, y_test_predict)))

print('MSE is {}'.format(MSE))
print('RMSE is {}'.format(RMSE))

R2 = r2_score(y_test, y_test_predict)

print('R^2 is {}'.format(R2))

print("Coefficient: \n", model.coef_)
print("\n Intercept: ", model.intercept_)
# Out:
# MSE is 55468022187.655266
# RMSE is 235516.50088190267
# R^2 is 0.9465973557921307
# Coefficient:
#  [-6.41706645e-02  2.87116246e-02  3.15438285e+01  1.73303727e+03
#   1.19002270e+03  2.93771312e+04 -1.54295235e+04  9.76985868e+03
#   2.48080375e+03 -6.14587896e-01  1.22548897e+02 -2.64926886e-01
#   6.85432406e-02  7.30257718e+02  5.09948378e+01]
#
#  Intercept:  -65942215.65452539

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

m = RandomForestRegressor()
m.fit(X_train, Y_train)
y_pred = m.predict(X_test)

# %%
MSE = mean_squared_error(y_test, y_test_predict)

RMSE = (np.sqrt(mean_squared_error(y_test, y_test_predict)))

print('MSE is {}'.format(MSE))
print('RMSE is {}'.format(RMSE))

R2 = r2_score(y_test, y_test_predict)

print('R^2 is {}'.format(R2))
# Out:
# MSE is 55468022187.655266
# RMSE is 235516.50088190267
# R^2 is 0.9465973557921307

# %%
RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
           max_features='auto', max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=1, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
           oob_score=False, random_state=0, verbose=0, warm_start=False)
